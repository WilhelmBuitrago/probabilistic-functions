# %%
from probabilistic_functions.plots2 import plot_function
from probabilistic_functions.plots import plot_function as plot_an
from probabilistic_functions.core import (Bernulli, Binomial, Poisson, Geometric, HyperGeometric,Uniform, Normal, Exponential, Weibull,Gamma, Beta, LogNormal, Pareto, Burr, Lindley,Birnbaum_Saunders, Gumbel)
from sympy import symbols,simplify

# %%
b =Bernulli()
b()
# Out:
# $\displaystyle
#         \textbf{\Large Bernoulli distribution} \\[6pt]
#         \text{Distribution mode:} \quad Discrete \\[6pt]
#         \text{Support:} \quad x \in \left\{0, 1\right\} \\[6pt]
#         \text{Parameters support:} \quad \theta \in \left[0, 1\right] \\[6pt]
#         \text{Function probability:} \quad \theta^{x} \left(1 - \theta\right)^{1 - x} \\[6pt]
#         \text{Generating function moment:} \quad \theta e^{t} - \theta + 1 \\[6pt]
#         \text{Cumulative distribution function:} \quad \begin{cases} \frac{x}{2} + \frac{1}{2} & \text{for}\: \theta = \frac{1}{2} \\\frac{- \theta^{2} + 2 \theta + \theta^{x + 1} \left(1 - \theta\right)^{1 - x} - 1}{2 \theta - 1} & \text{otherwise} \end{cases} \\[6pt]
#         \text{Survival function:} \quad \begin{cases} \frac{1 - x}{2} & \text{for}\: \theta = \frac{1}{2} \\\frac{\theta \left(\theta - \theta^{x} \left(1 - \theta\right)^{1 - x}\right)}{2 \theta - 1} & \text{otherwise} \end{cases} \\[6pt]
# ...

# %% [markdown]
# # Bernulli

# %%
plot_function(Bernulli(),"pmf",parameters={"p":[0.5,0.3,0.4]})

# %%
plot_function(Bernulli(),"cdf",parameters={"p":[0.5,0.3,0.4]})

# %%
plot_function(Bernulli(),"sf",parameters={"p":[0.5,0.3,0.4]})

# %% [markdown]
# # Binomial

# %%
plot_function(Binomial(),"pmf",parameters={"p":[0.5,0.3,0.4],"n":[5,10,15]},size=(10,10))

# %%
plot_function(Binomial(),"cdf",parameters={"p":[0.5,0.3,0.4],"n":[5,10,15]},size=(10,10))

# %%
plot_function(Binomial(),"sf",parameters={"p":[0.5,0.3,0.4],"n":[5,10,15]},size=(10,10))

# %% [markdown]
# # Geometrica

# %%
plot_function(Geometric(),"pmf",parameters={"p":[0.5,0.3,0.4]})

# %%
plot_function(Geometric(),"cdf",parameters={"p":[0.5,0.3,0.4]})

# %%
plot_function(Geometric(),"sf",parameters={"p":[0.5,0.3,0.4]})

# %% [markdown]
# # HiperGeometrica

# %%
plot_function(HyperGeometric(),"pmf",parameters={"N":[15,20,30],"K":[5,10,15],"n":[3,5,7]},size=(10,10))

# %%
plot_function(HyperGeometric(),"cdf",parameters={"N":[15,20,30],"K":[5,10,15],"n":[3,5,7]},size=(10,10))

# %%
plot_function(HyperGeometric(),"sf",parameters={"N":[15,20,30],"K":[5,10,15],"n":[3,5,7]},size=(10,10))

# %% [markdown]
# # Poisson

# %%
plot_function(Poisson(),"pmf",parameters={"l":[0.4,1,3]})

# %%
plot_function(Poisson(),"cdf",parameters={"l":[0.4,1,3]},size=(10,4))

# %%
plot_function(Poisson(),"sf",parameters={"l":[0.4,1,3]},size=(10,4))

# %% [markdown]
# # Uniforme

# %%
plot_function(Uniform(),"pdf",parameters={"a":[0.4,1,3],"b":[4,6,10]},size=(10,10))

# %%
plot_function(Uniform(),"cdf",parameters={"a":[0.4,1,3],"b":[4,6,10]},size=(10,10))

# %%
plot_function(Uniform(),"sf",parameters={"a":[0.4,1,3],"b":[4,6,10]},size=(10,10))

# %% [markdown]
# # Exponential

# %%
plot_function(Exponential(),"pdf",parameters={"l":[0.4,1,3]})

# %%
plot_function(Exponential(),"cdf",parameters={"l":[0.4,1,3]})

# %%
plot_function(Exponential(),"sf",parameters={"l":[0.4,1,3]})

# %% [markdown]
# # Normal

# %%
plot_function(Normal(),"pdf",parameters={"m":[0,1,10],"v":[1,2,3]},size=(10,10))

# %%
plot_function(Normal(),"cdf",parameters={"m":[0,1,10],"v":[1,2,3]},size=(10,10))

# %%
plot_function(Normal(),"sf",parameters={"m":[0,1,10],"v":[1,2,3]},size=(10,10))

# %% [markdown]
# # Weibull

# %%
plot_function(Weibull(),"pdf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %%
plot_function(Weibull(),"cdf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %%
plot_function(Weibull(),"sf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %% [markdown]
# # Gamma

# %%
plot_function(Gamma(),"pdf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %%
plot_function(Gamma(),"cdf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %%
plot_function(Gamma(),"sf",parameters={"a":[0.5,1,2],"b":[0.5,1,2]},size=(10,10))

# %% [markdown]
# # Beta

# %% [markdown]
# ## Error

# %% [markdown]
# # LogNormal

# %%
plot_function(LogNormal(),"pdf",parameters={"m":[0,1,2],"v":[0.5,1,2]},size=(10,10))

# %% [markdown]
# ## Error

# %% [markdown]
# # Lindley

# %%
plot_function(Lindley(),"pdf",parameters={"p":[0.5,0.6,0.7]})

# %%
plot_function(Lindley(),"cdf",parameters={"p":[0.5,0.6,0.7]})

# %%
plot_function(Lindley(),"sf",parameters={"p":[0.5,0.6,0.7]})
